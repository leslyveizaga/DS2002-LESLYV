# %%
# Import Dataset from Kaggle
# !pip install --upgrade kagglehub
import kagglehub
import pandas as pd
import json
import csv
import os
import sqlite3


# Download latest version
path = kagglehub.dataset_download("s3programmer/disease-diagnosis-dataset")

print("Path to dataset files:", path)
files = os.listdir(path)
print("Files in dataset:", files)
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Collecting kagglehub
#   Downloading kagglehub-0.3.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2024.8.30)
# Downloading kagglehub-0.3.3-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: kagglehub
#   Attempting uninstall: kagglehub
#     Found existing installation: kagglehub 0.3.2
#     Uninstalling kagglehub-0.3.2:
#       Successfully uninstalled kagglehub-0.3.2
# Successfully installed kagglehub-0.3.3
# Downloading from https://www.kaggle.com/api/v1/datasets/download/s3programmer/disease-diagnosis-dataset?dataset_version_number=1...
# 100%|██████████| 32.8k/32.8k [00:00<00:00, 37.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/s3programmer/disease-diagnosis-dataset/versions/1
# Files in dataset: ['disease_diagnosis.csv']

# %%
# Loaded CSV from kaggle
csv_data = os.path.join(path, "disease_diagnosis.csv")
df = pd.read_csv(csv_data)
print(df.head())
# Out:
#    Patient_ID  Age  Gender            Symptom_1    Symptom_2 Symptom_3  \
# 0           1   74    Male              Fatigue  Sore throat     Fever
# 1           2   66  Female          Sore throat      Fatigue     Cough
# 2           3   32    Male            Body ache  Sore throat   Fatigue
# 3           4   21  Female  Shortness of breath     Headache     Cough
# 4           5   53    Male           Runny nose  Sore throat   Fatigue
#
#    Heart_Rate_bpm  Body_Temperature_C Blood_Pressure_mmHg  \
# 0              69                39.4              132/91
# 1              95                39.0              174/98
# 2              77                36.8              136/60
# 3              72                38.9              147/82
# 4             100                36.6             109/106
#
#    Oxygen_Saturation_% Diagnosis  Severity       Treatment_Plan
# 0                   94       Flu  Moderate  Medication and rest
# 1                   98   Healthy      Mild      Rest and fluids
# 2                   96   Healthy      Mild      Rest and fluids
# 3                   99   Healthy      Mild      Rest and fluids
# 4                   92   Healthy      Mild      Rest and fluids

# %%
# Modifying CSV file BEFORE converting
# (selected 3 columns and added NEW health risk column)

def mod_columns(df, selected_columns=None, new_col_name=None, new_col_value=None):
    if three_selected_columns:
        df = df[selected_columns].copy()
        # Calculated a health risk score based on age and diagnosis
    if 'Age' in df.columns and 'Diagnosis' in df.columns:
        df['Risk_Score'] = df.apply(lambda row: row['Age'] * (2 if 'Severe' in row['Diagnosis'] else 1), axis=1)
    return df

three_selected_columns = ['Age', 'Diagnosis', 'Gender']


df_modified = mod_columns(df, three_selected_columns)
print("Modified DataFrame:")
print(df_modified.head())
# Out:
# Modified DataFrame:
#    Age Diagnosis  Gender  Risk_Score
# 0   74       Flu    Male          74
# 1   66   Healthy  Female          66
# 2   32   Healthy    Male          32
# 3   21   Healthy  Female          21
# 4   53   Healthy    Male          53

# %%
#function to convert CSV to JSON
def convert_to_json(df, output_file):
    df.to_json(output_file, orient='records', lines=True)
    print(f"DataFrame converted to JSON and saved to {output_file}.")

    #JSON file
    print("\nDisplaying the converted JSON data:")
    with open(output_file, 'r') as f:
        json_data = f.read()
        print(json_data)

# function to save CSV to SQL
def convert_to_sql(df, db_name, table_name):
    conn = sqlite3.connect(db_name)
    df.to_sql(table_name, conn, if_exists='replace', index=False)
    conn.commit()

    print(f"DataFrame saved to SQLite database {db_name}, table: {table_name}.")

    #SQL table
    print("\nDisplaying the data from the SQL table:")
    query = f"SELECT * FROM {table_name} LIMIT 5;"
    df_sql = pd.read_sql(query, conn)
    print(df_sql.head())

    conn.close()

#processor to choose the output format
def processor_data(input_file, output_format, output_file=None, db_name=None, table_name=None):
    df = pd.read_csv(input_file)
    if output_format == 'json':
        if output_file is None:
            output_file = 'output_data.json'
        convert_to_json(df_modified, output_file)

    elif output_format == 'sql':
        if db_name is None:
            db_name = 'output_database.db'
        if table_name is None:
            table_name = 'output_table'
        convert_to_sql(df_modified, db_name, table_name)

    else:
        print("Invalid output format. Choose either 'json' or 'sql'.")

# JSON OR SQL option
output_format_json = 'json'
output_format_sql = 'sql'

#convert to JSON and display:
processor_data(csv_file, output_format_json, output_file=output_json_file)
# Out:
# DataFrame converted to JSON and saved to disease_file.json.
#
# Displaying the converted JSON data:
# {"Age":74,"Diagnosis":"Flu","Gender":"Male","Risk_Score":74}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":66}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":32}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":53}
# {"Age":22,"Diagnosis":"Flu","Gender":"Male","Risk_Score":22}
# {"Age":21,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":21}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":56,"Diagnosis":"Cold","Gender":"Female","Risk_Score":56}
# {"Age":53,"Diagnosis":"Flu","Gender":"Male","Risk_Score":53}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":72}
# {"Age":28,"Diagnosis":"Cold","Gender":"Female","Risk_Score":28}
# {"Age":78,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":78}
# {"Age":23,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":23}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":19,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":19}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":46}
# {"Age":68,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":68}
# {"Age":31,"Diagnosis":"Cold","Gender":"Male","Risk_Score":31}
# {"Age":46,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":46}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":58}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":30,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":30}
# {"Age":69,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":69}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":60}
# {"Age":45,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":45}
# {"Age":49,"Diagnosis":"Flu","Gender":"Female","Risk_Score":49}
# {"Age":75,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":75}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":51}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":35}
# {"Age":18,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":18}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":62}
# {"Age":24,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":24}
# {"Age":64,"Diagnosis":"Flu","Gender":"Female","Risk_Score":64}
# {"Age":53,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":53}
# {"Age":53,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":53}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":62}
# {"Age":71,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":71}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":27}
# {"Age":67,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":67}
# {"Age":78,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":78}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":78,"Diagnosis":"Flu","Gender":"Female","Risk_Score":78}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":32}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":38}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":36}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":71}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":37}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":55}
# {"Age":31,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":31}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":49,"Diagnosis":"Cold","Gender":"Female","Risk_Score":49}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":38}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":50}
# {"Age":38,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":38}
# {"Age":77,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":77}
# {"Age":49,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":49}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":45}
# {"Age":76,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":76}
# {"Age":47,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":47}
# {"Age":49,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":49}
# {"Age":33,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":33}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":23}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":29}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":59}
# {"Age":32,"Diagnosis":"Flu","Gender":"Female","Risk_Score":32}
# {"Age":50,"Diagnosis":"Cold","Gender":"Male","Risk_Score":50}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":65}
# {"Age":70,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":70}
# {"Age":66,"Diagnosis":"Flu","Gender":"Male","Risk_Score":66}
# {"Age":20,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":20}
# {"Age":31,"Diagnosis":"Cold","Gender":"Female","Risk_Score":31}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":51}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":24}
# {"Age":64,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":64}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":55,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":55}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":41}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":27}
# {"Age":53,"Diagnosis":"Flu","Gender":"Female","Risk_Score":53}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":63}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":70}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":70}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":31,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":31}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":39,"Diagnosis":"Flu","Gender":"Female","Risk_Score":39}
# {"Age":71,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":71}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":72}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":62}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":35}
# {"Age":67,"Diagnosis":"Flu","Gender":"Male","Risk_Score":67}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":63}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":44}
# {"Age":53,"Diagnosis":"Cold","Gender":"Female","Risk_Score":53}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":54}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":54}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":34}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":44}
# {"Age":69,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":69}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":59}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":54}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":51}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":36}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":57}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":34}
# {"Age":57,"Diagnosis":"Flu","Gender":"Male","Risk_Score":57}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":58}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":29}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":52}
# {"Age":69,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":69}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":47}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":64}
# {"Age":50,"Diagnosis":"Flu","Gender":"Male","Risk_Score":50}
# {"Age":30,"Diagnosis":"Cold","Gender":"Male","Risk_Score":30}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":58}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":27}
# {"Age":68,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":68}
# {"Age":68,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":68}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":25}
# {"Age":46,"Diagnosis":"Cold","Gender":"Male","Risk_Score":46}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":36}
# {"Age":25,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":25}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":54}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":34}
# {"Age":42,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":42}
# {"Age":73,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":73}
# {"Age":57,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":57}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":25}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":45}
# {"Age":77,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":77}
# {"Age":33,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":33}
# {"Age":64,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":64}
# {"Age":18,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":18}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":63}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":70}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":26}
# {"Age":46,"Diagnosis":"Flu","Gender":"Male","Risk_Score":46}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":40}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":65,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":65}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":36}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":29}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":71}
# {"Age":23,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":23}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":54}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":59}
# {"Age":55,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":55}
# {"Age":75,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":75}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":41}
# {"Age":25,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":25}
# {"Age":46,"Diagnosis":"Flu","Gender":"Male","Risk_Score":46}
# {"Age":72,"Diagnosis":"Cold","Gender":"Female","Risk_Score":72}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":39}
# {"Age":77,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":77}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":46}
# {"Age":74,"Diagnosis":"Flu","Gender":"Male","Risk_Score":74}
# {"Age":35,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":35}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":51}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":63}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":34}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":54}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":54}
# {"Age":65,"Diagnosis":"Flu","Gender":"Male","Risk_Score":65}
# {"Age":57,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":57}
# {"Age":75,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":75}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":39}
# {"Age":49,"Diagnosis":"Cold","Gender":"Male","Risk_Score":49}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":37}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":44}
# {"Age":46,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":46}
# {"Age":46,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":46}
# {"Age":71,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":71}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":52}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":42,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":42}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":39}
# {"Age":59,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":59}
# {"Age":27,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":27}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":62}
# {"Age":47,"Diagnosis":"Flu","Gender":"Female","Risk_Score":47}
# {"Age":78,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":78}
# {"Age":62,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":62}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":51,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":51}
# {"Age":55,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":55}
# {"Age":67,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":67}
# {"Age":19,"Diagnosis":"Flu","Gender":"Female","Risk_Score":19}
# {"Age":69,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":69}
# {"Age":71,"Diagnosis":"Cold","Gender":"Female","Risk_Score":71}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":52}
# {"Age":78,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":78}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":63}
# {"Age":69,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":69}
# {"Age":63,"Diagnosis":"Cold","Gender":"Male","Risk_Score":63}
# {"Age":48,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":48}
# {"Age":31,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":31}
# {"Age":73,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":73}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":59}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":64}
# {"Age":27,"Diagnosis":"Cold","Gender":"Female","Risk_Score":27}
# {"Age":65,"Diagnosis":"Cold","Gender":"Male","Risk_Score":65}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":24}
# {"Age":56,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":56}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":43,"Diagnosis":"Flu","Gender":"Male","Risk_Score":43}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":68,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":68}
# {"Age":29,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":29}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":63}
# {"Age":77,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":77}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":49}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":59}
# {"Age":46,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":46}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":58}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":40}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":43}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":66}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":24}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":65}
# {"Age":37,"Diagnosis":"Cold","Gender":"Male","Risk_Score":37}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":36}
# {"Age":54,"Diagnosis":"Flu","Gender":"Female","Risk_Score":54}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":36}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":19}
# {"Age":20,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":20}
# {"Age":56,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":56}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":62}
# {"Age":23,"Diagnosis":"Flu","Gender":"Male","Risk_Score":23}
# {"Age":18,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":18}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":38}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":72}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":51}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":39}
# {"Age":27,"Diagnosis":"Flu","Gender":"Female","Risk_Score":27}
# {"Age":68,"Diagnosis":"Flu","Gender":"Female","Risk_Score":68}
# {"Age":28,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":28}
# {"Age":23,"Diagnosis":"Cold","Gender":"Male","Risk_Score":23}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":77,"Diagnosis":"Flu","Gender":"Female","Risk_Score":77}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":62,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":62}
# {"Age":56,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":56}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":67,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":67}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":39}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":25}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":37}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":35}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":30}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":34}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":66}
# {"Age":33,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":33}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":63}
# {"Age":18,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":18}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":26}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":66}
# {"Age":78,"Diagnosis":"Cold","Gender":"Female","Risk_Score":78}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":37}
# {"Age":64,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":64}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":25}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":34}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":26}
# {"Age":22,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":22}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":57}
# {"Age":67,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":67}
# {"Age":47,"Diagnosis":"Flu","Gender":"Female","Risk_Score":47}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":27}
# {"Age":77,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":77}
# {"Age":35,"Diagnosis":"Cold","Gender":"Male","Risk_Score":35}
# {"Age":35,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":35}
# {"Age":77,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":77}
# {"Age":23,"Diagnosis":"Flu","Gender":"Male","Risk_Score":23}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":66}
# {"Age":31,"Diagnosis":"Flu","Gender":"Male","Risk_Score":31}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":24}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":43}
# {"Age":48,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":48}
# {"Age":50,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":50}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":22,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":22}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":46,"Diagnosis":"Flu","Gender":"Female","Risk_Score":46}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":36}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":43}
# {"Age":27,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":27}
# {"Age":53,"Diagnosis":"Flu","Gender":"Male","Risk_Score":53}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":55}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":50}
# {"Age":63,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":63}
# {"Age":42,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":42}
# {"Age":48,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":48}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":79}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":39}
# {"Age":32,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":32}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":35}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":50}
# {"Age":78,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":78}
# {"Age":49,"Diagnosis":"Cold","Gender":"Female","Risk_Score":49}
# {"Age":48,"Diagnosis":"Cold","Gender":"Female","Risk_Score":48}
# {"Age":42,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":42}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":50}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":29}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":58}
# {"Age":26,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":26}
# {"Age":51,"Diagnosis":"Flu","Gender":"Male","Risk_Score":51}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":35}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":59}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":41}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":25}
# {"Age":19,"Diagnosis":"Cold","Gender":"Male","Risk_Score":19}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":65}
# {"Age":38,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":38}
# {"Age":69,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":69}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":47}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":44,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":44}
# {"Age":47,"Diagnosis":"Cold","Gender":"Female","Risk_Score":47}
# {"Age":37,"Diagnosis":"Flu","Gender":"Female","Risk_Score":37}
# {"Age":75,"Diagnosis":"Flu","Gender":"Female","Risk_Score":75}
# {"Age":57,"Diagnosis":"Flu","Gender":"Female","Risk_Score":57}
# {"Age":69,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":69}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":59}
# {"Age":22,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":22}
# {"Age":76,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":76}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":24}
# {"Age":29,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":29}
# {"Age":53,"Diagnosis":"Cold","Gender":"Male","Risk_Score":53}
# {"Age":40,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":40}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":46}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":60}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":44,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":44}
# {"Age":25,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":25}
# {"Age":29,"Diagnosis":"Flu","Gender":"Male","Risk_Score":29}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":65}
# {"Age":35,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":35}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":29}
# {"Age":24,"Diagnosis":"Flu","Gender":"Female","Risk_Score":24}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":39}
# {"Age":49,"Diagnosis":"Flu","Gender":"Female","Risk_Score":49}
# {"Age":21,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":21}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":29}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":51}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":54}
# {"Age":50,"Diagnosis":"Flu","Gender":"Female","Risk_Score":50}
# {"Age":23,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":23}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":26}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":53}
# {"Age":57,"Diagnosis":"Flu","Gender":"Female","Risk_Score":57}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":53}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":79}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":60}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":19}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":27}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":60}
# {"Age":23,"Diagnosis":"Flu","Gender":"Female","Risk_Score":23}
# {"Age":65,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":65}
# {"Age":75,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":75}
# {"Age":75,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":75}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":19}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":63}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":37}
# {"Age":28,"Diagnosis":"Flu","Gender":"Male","Risk_Score":28}
# {"Age":34,"Diagnosis":"Flu","Gender":"Female","Risk_Score":34}
# {"Age":22,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":22}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":64}
# {"Age":66,"Diagnosis":"Cold","Gender":"Female","Risk_Score":66}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":23}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":37}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":58}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":26}
# {"Age":79,"Diagnosis":"Cold","Gender":"Female","Risk_Score":79}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":30}
# {"Age":31,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":31}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":24}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":23}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":21}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":61}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":41}
# {"Age":67,"Diagnosis":"Flu","Gender":"Female","Risk_Score":67}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":34}
# {"Age":70,"Diagnosis":"Flu","Gender":"Female","Risk_Score":70}
# {"Age":53,"Diagnosis":"Flu","Gender":"Female","Risk_Score":53}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":34}
# {"Age":52,"Diagnosis":"Flu","Gender":"Male","Risk_Score":52}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":37}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":34}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":32}
# {"Age":67,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":67}
# {"Age":28,"Diagnosis":"Cold","Gender":"Male","Risk_Score":28}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":59}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":27}
# {"Age":32,"Diagnosis":"Flu","Gender":"Female","Risk_Score":32}
# {"Age":57,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":57}
# {"Age":47,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":47}
# {"Age":40,"Diagnosis":"Flu","Gender":"Male","Risk_Score":40}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":32}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":30}
# {"Age":56,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":56}
# {"Age":64,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":64}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":70}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":21}
# {"Age":44,"Diagnosis":"Cold","Gender":"Female","Risk_Score":44}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":51}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":60}
# {"Age":22,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":22}
# {"Age":60,"Diagnosis":"Cold","Gender":"Male","Risk_Score":60}
# {"Age":40,"Diagnosis":"Flu","Gender":"Male","Risk_Score":40}
# {"Age":46,"Diagnosis":"Flu","Gender":"Female","Risk_Score":46}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":19}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":35}
# {"Age":57,"Diagnosis":"Flu","Gender":"Female","Risk_Score":57}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":64}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":41,"Diagnosis":"Cold","Gender":"Male","Risk_Score":41}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":79}
# {"Age":21,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":21}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":53,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":53}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":43}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":36}
# {"Age":55,"Diagnosis":"Cold","Gender":"Male","Risk_Score":55}
# {"Age":20,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":20}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":40}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":39}
# {"Age":52,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":52}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":35}
# {"Age":69,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":69}
# {"Age":25,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":25}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":30}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":55}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":60}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":34}
# {"Age":76,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":76}
# {"Age":56,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":56}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":30}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":52}
# {"Age":52,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":52}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":36}
# {"Age":49,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":49}
# {"Age":50,"Diagnosis":"Flu","Gender":"Male","Risk_Score":50}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":51}
# {"Age":41,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":41}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":62}
# {"Age":74,"Diagnosis":"Flu","Gender":"Female","Risk_Score":74}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":65}
# {"Age":19,"Diagnosis":"Cold","Gender":"Male","Risk_Score":19}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":18,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":18}
# {"Age":21,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":21}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":72}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":24}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":40}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":66}
# {"Age":65,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":65}
# {"Age":69,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":69}
# {"Age":47,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":47}
# {"Age":78,"Diagnosis":"Flu","Gender":"Male","Risk_Score":78}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":28,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":28}
# {"Age":18,"Diagnosis":"Flu","Gender":"Male","Risk_Score":18}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":44}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":44,"Diagnosis":"Cold","Gender":"Female","Risk_Score":44}
# {"Age":27,"Diagnosis":"Cold","Gender":"Female","Risk_Score":27}
# {"Age":76,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":76}
# {"Age":45,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":45}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":44}
# {"Age":37,"Diagnosis":"Cold","Gender":"Female","Risk_Score":37}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":64}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":24}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":72}
# {"Age":39,"Diagnosis":"Cold","Gender":"Male","Risk_Score":39}
# {"Age":55,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":55}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":63}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":47}
# {"Age":78,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":78}
# {"Age":33,"Diagnosis":"Flu","Gender":"Male","Risk_Score":33}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":26}
# {"Age":57,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":57}
# {"Age":53,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":53}
# {"Age":29,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":29}
# {"Age":58,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":58}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":27}
# {"Age":56,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":56}
# {"Age":52,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":52}
# {"Age":40,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":40}
# {"Age":41,"Diagnosis":"Cold","Gender":"Male","Risk_Score":41}
# {"Age":71,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":71}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":38}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":60,"Diagnosis":"Flu","Gender":"Male","Risk_Score":60}
# {"Age":36,"Diagnosis":"Flu","Gender":"Female","Risk_Score":36}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":32}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":49}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":19}
# {"Age":56,"Diagnosis":"Flu","Gender":"Female","Risk_Score":56}
# {"Age":71,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":71}
# {"Age":36,"Diagnosis":"Flu","Gender":"Male","Risk_Score":36}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":53}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":57,"Diagnosis":"Flu","Gender":"Female","Risk_Score":57}
# {"Age":40,"Diagnosis":"Flu","Gender":"Female","Risk_Score":40}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":52,"Diagnosis":"Flu","Gender":"Male","Risk_Score":52}
# {"Age":22,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":22}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":61}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":61}
# {"Age":65,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":65}
# {"Age":29,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":29}
# {"Age":51,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":51}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":60}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":19}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":45}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":65}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":54}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":62}
# {"Age":72,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":72}
# {"Age":46,"Diagnosis":"Cold","Gender":"Female","Risk_Score":46}
# {"Age":67,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":67}
# {"Age":35,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":35}
# {"Age":34,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":34}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":57}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":58}
# {"Age":28,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":28}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":61}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":35}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":25}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":32}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":35}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":23}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":58}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":28,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":28}
# {"Age":78,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":78}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":72}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":74}
# {"Age":53,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":53}
# {"Age":58,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":58}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":74}
# {"Age":33,"Diagnosis":"Flu","Gender":"Male","Risk_Score":33}
# {"Age":34,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":34}
# {"Age":47,"Diagnosis":"Cold","Gender":"Female","Risk_Score":47}
# {"Age":61,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":61}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":43}
# {"Age":59,"Diagnosis":"Cold","Gender":"Female","Risk_Score":59}
# {"Age":31,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":31}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":71}
# {"Age":49,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":49}
# {"Age":79,"Diagnosis":"Flu","Gender":"Female","Risk_Score":79}
# {"Age":30,"Diagnosis":"Cold","Gender":"Male","Risk_Score":30}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":27}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":51,"Diagnosis":"Flu","Gender":"Female","Risk_Score":51}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":46}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":41}
# {"Age":20,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":20}
# {"Age":45,"Diagnosis":"Cold","Gender":"Male","Risk_Score":45}
# {"Age":48,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":48}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":46}
# {"Age":57,"Diagnosis":"Flu","Gender":"Male","Risk_Score":57}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":74}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":60}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":30}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":27}
# {"Age":25,"Diagnosis":"Flu","Gender":"Female","Risk_Score":25}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":32}
# {"Age":61,"Diagnosis":"Cold","Gender":"Female","Risk_Score":61}
# {"Age":37,"Diagnosis":"Cold","Gender":"Female","Risk_Score":37}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":40}
# {"Age":52,"Diagnosis":"Cold","Gender":"Female","Risk_Score":52}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":63}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":64,"Diagnosis":"Flu","Gender":"Male","Risk_Score":64}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":76,"Diagnosis":"Flu","Gender":"Female","Risk_Score":76}
# {"Age":32,"Diagnosis":"Flu","Gender":"Male","Risk_Score":32}
# {"Age":69,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":69}
# {"Age":25,"Diagnosis":"Cold","Gender":"Female","Risk_Score":25}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":66}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":44}
# {"Age":51,"Diagnosis":"Flu","Gender":"Male","Risk_Score":51}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":65}
# {"Age":78,"Diagnosis":"Cold","Gender":"Male","Risk_Score":78}
# {"Age":27,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":27}
# {"Age":56,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":56}
# {"Age":22,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":22}
# {"Age":73,"Diagnosis":"Cold","Gender":"Male","Risk_Score":73}
# {"Age":74,"Diagnosis":"Cold","Gender":"Male","Risk_Score":74}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":60}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":62}
# {"Age":68,"Diagnosis":"Flu","Gender":"Female","Risk_Score":68}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":52}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":63}
# {"Age":60,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":60}
# {"Age":35,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":35}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":35}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":41}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":53}
# {"Age":78,"Diagnosis":"Flu","Gender":"Male","Risk_Score":78}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":74}
# {"Age":38,"Diagnosis":"Flu","Gender":"Female","Risk_Score":38}
# {"Age":31,"Diagnosis":"Flu","Gender":"Male","Risk_Score":31}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":27,"Diagnosis":"Flu","Gender":"Female","Risk_Score":27}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":49}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":42,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":42}
# {"Age":47,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":47}
# {"Age":27,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":27}
# {"Age":30,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":30}
# {"Age":29,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":29}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":64}
# {"Age":31,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":31}
# {"Age":33,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":33}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":74}
# {"Age":54,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":54}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":51}
# {"Age":57,"Diagnosis":"Flu","Gender":"Male","Risk_Score":57}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":51}
# {"Age":26,"Diagnosis":"Flu","Gender":"Male","Risk_Score":26}
# {"Age":37,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":37}
# {"Age":24,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":24}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":50}
# {"Age":60,"Diagnosis":"Cold","Gender":"Male","Risk_Score":60}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":30,"Diagnosis":"Flu","Gender":"Male","Risk_Score":30}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":32}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":29}
# {"Age":59,"Diagnosis":"Cold","Gender":"Male","Risk_Score":59}
# {"Age":18,"Diagnosis":"Flu","Gender":"Female","Risk_Score":18}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":46}
# {"Age":33,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":33}
# {"Age":67,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":67}
# {"Age":65,"Diagnosis":"Flu","Gender":"Male","Risk_Score":65}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":56,"Diagnosis":"Cold","Gender":"Female","Risk_Score":56}
# {"Age":71,"Diagnosis":"Flu","Gender":"Male","Risk_Score":71}
# {"Age":21,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":21}
# {"Age":31,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":31}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":62}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":39}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":38}
# {"Age":59,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":59}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":33,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":33}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":37}
# {"Age":40,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":40}
# {"Age":30,"Diagnosis":"Flu","Gender":"Female","Risk_Score":30}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":44}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":29}
# {"Age":65,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":65}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":35}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":38,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":38}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":35}
# {"Age":47,"Diagnosis":"Flu","Gender":"Male","Risk_Score":47}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":26}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":38}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":37}
# {"Age":35,"Diagnosis":"Cold","Gender":"Male","Risk_Score":35}
# {"Age":29,"Diagnosis":"Flu","Gender":"Female","Risk_Score":29}
# {"Age":41,"Diagnosis":"Cold","Gender":"Female","Risk_Score":41}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":53}
# {"Age":32,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":32}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":79}
# {"Age":52,"Diagnosis":"Cold","Gender":"Male","Risk_Score":52}
# {"Age":79,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":79}
# {"Age":75,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":75}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":74}
# {"Age":76,"Diagnosis":"Flu","Gender":"Male","Risk_Score":76}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":29}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":61}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":25}
# {"Age":38,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":38}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":30}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":78,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":78}
# {"Age":58,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":58}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":68,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":68}
# {"Age":37,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":37}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":74}
# {"Age":76,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":76}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":34}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":58}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":40}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# ...
# {"Age":58,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":58}
# {"Age":21,"Diagnosis":"Flu","Gender":"Female","Risk_Score":21}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":53}
# {"Age":75,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":75}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":61}
# {"Age":51,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":51}
# {"Age":31,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":31}
# {"Age":66,"Diagnosis":"Flu","Gender":"Male","Risk_Score":66}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":25}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":40}
# {"Age":42,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":42}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":27}
# {"Age":65,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":65}
# {"Age":31,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":31}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":46}
# {"Age":74,"Diagnosis":"Cold","Gender":"Female","Risk_Score":74}
# {"Age":34,"Diagnosis":"Flu","Gender":"Male","Risk_Score":34}
# {"Age":76,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":76}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":50}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":45}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":29}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":43}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":26}
# {"Age":70,"Diagnosis":"Cold","Gender":"Female","Risk_Score":70}
# {"Age":19,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":19}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":58,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":58}
# {"Age":48,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":48}
# {"Age":25,"Diagnosis":"Flu","Gender":"Female","Risk_Score":25}
# {"Age":79,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":79}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":63}
# {"Age":35,"Diagnosis":"Cold","Gender":"Male","Risk_Score":35}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":36}
# {"Age":43,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":43}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":72}
# {"Age":46,"Diagnosis":"Flu","Gender":"Female","Risk_Score":46}
# {"Age":71,"Diagnosis":"Flu","Gender":"Male","Risk_Score":71}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":21}
# {"Age":20,"Diagnosis":"Cold","Gender":"Male","Risk_Score":20}
# {"Age":69,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":69}
# {"Age":40,"Diagnosis":"Flu","Gender":"Male","Risk_Score":40}
# {"Age":65,"Diagnosis":"Flu","Gender":"Female","Risk_Score":65}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":41}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":46}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":52}
# {"Age":37,"Diagnosis":"Flu","Gender":"Female","Risk_Score":37}
# {"Age":66,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":66}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":50}
# {"Age":45,"Diagnosis":"Flu","Gender":"Female","Risk_Score":45}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":63}
# {"Age":45,"Diagnosis":"Flu","Gender":"Female","Risk_Score":45}
# {"Age":28,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":28}
# {"Age":49,"Diagnosis":"Flu","Gender":"Female","Risk_Score":49}
# {"Age":42,"Diagnosis":"Cold","Gender":"Male","Risk_Score":42}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":47}
# {"Age":42,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":42}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":41}
# {"Age":18,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":18}
# {"Age":32,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":32}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":73}
# {"Age":71,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":71}
# {"Age":72,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":72}
# {"Age":27,"Diagnosis":"Flu","Gender":"Male","Risk_Score":27}
# {"Age":76,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":76}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":26}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":46}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":41}
# {"Age":61,"Diagnosis":"Flu","Gender":"Male","Risk_Score":61}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":62}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":45}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":58}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":27}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":38}
# {"Age":78,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":78}
# {"Age":25,"Diagnosis":"Cold","Gender":"Female","Risk_Score":25}
# {"Age":44,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":44}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":66}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":50}
# {"Age":42,"Diagnosis":"Cold","Gender":"Male","Risk_Score":42}
# {"Age":27,"Diagnosis":"Flu","Gender":"Male","Risk_Score":27}
# {"Age":74,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":74}
# {"Age":26,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":26}
# {"Age":18,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":18}
# {"Age":44,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":44}
# {"Age":62,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":62}
# {"Age":46,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":46}
# {"Age":75,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":75}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":70}
# {"Age":22,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":22}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":34}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":39}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":49}
# {"Age":62,"Diagnosis":"Flu","Gender":"Female","Risk_Score":62}
# {"Age":50,"Diagnosis":"Flu","Gender":"Female","Risk_Score":50}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":53}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":40}
# {"Age":63,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":63}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":35}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":40}
# {"Age":26,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":26}
# {"Age":24,"Diagnosis":"Cold","Gender":"Male","Risk_Score":24}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":30}
# {"Age":30,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":30}
# {"Age":31,"Diagnosis":"Flu","Gender":"Male","Risk_Score":31}
# {"Age":48,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":48}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":50}
# {"Age":75,"Diagnosis":"Flu","Gender":"Female","Risk_Score":75}
# {"Age":29,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":29}
# {"Age":40,"Diagnosis":"Cold","Gender":"Male","Risk_Score":40}
# {"Age":23,"Diagnosis":"Cold","Gender":"Female","Risk_Score":23}
# {"Age":71,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":71}
# {"Age":24,"Diagnosis":"Flu","Gender":"Male","Risk_Score":24}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":21,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":21}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":43}
# {"Age":28,"Diagnosis":"Cold","Gender":"Male","Risk_Score":28}
# {"Age":74,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":74}
# {"Age":23,"Diagnosis":"Flu","Gender":"Female","Risk_Score":23}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":53}
# {"Age":41,"Diagnosis":"Cold","Gender":"Female","Risk_Score":41}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":19}
# {"Age":39,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":39}
# {"Age":27,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":27}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":43}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":49}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":40,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":40}
# {"Age":64,"Diagnosis":"Cold","Gender":"Male","Risk_Score":64}
# {"Age":18,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":18}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":19}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":46}
# {"Age":71,"Diagnosis":"Flu","Gender":"Male","Risk_Score":71}
# {"Age":19,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":19}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":38}
# {"Age":46,"Diagnosis":"Flu","Gender":"Male","Risk_Score":46}
# {"Age":21,"Diagnosis":"Pneumonia","Gender":"Female","Risk_Score":21}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":66}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":23}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":71}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":71}
# {"Age":47,"Diagnosis":"Flu","Gender":"Female","Risk_Score":47}
# {"Age":50,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":50}
# {"Age":41,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":41}
# {"Age":28,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":28}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":60}
# {"Age":67,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":67}
# {"Age":28,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":28}
# {"Age":55,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":55}
# {"Age":60,"Diagnosis":"Flu","Gender":"Female","Risk_Score":60}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":30}
# {"Age":35,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":35}
# {"Age":53,"Diagnosis":"Cold","Gender":"Male","Risk_Score":53}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":34}
# {"Age":72,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":72}
# {"Age":78,"Diagnosis":"Flu","Gender":"Female","Risk_Score":78}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":64}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":58}
# {"Age":28,"Diagnosis":"Flu","Gender":"Male","Risk_Score":28}
# {"Age":44,"Diagnosis":"Flu","Gender":"Female","Risk_Score":44}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":52}
# {"Age":74,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":74}
# {"Age":40,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":40}
# {"Age":30,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":30}
# {"Age":26,"Diagnosis":"Flu","Gender":"Male","Risk_Score":26}
# {"Age":66,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":66}
# {"Age":52,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":52}
# {"Age":53,"Diagnosis":"Flu","Gender":"Female","Risk_Score":53}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":39,"Diagnosis":"Flu","Gender":"Male","Risk_Score":39}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":43,"Diagnosis":"Flu","Gender":"Male","Risk_Score":43}
# {"Age":44,"Diagnosis":"Flu","Gender":"Female","Risk_Score":44}
# {"Age":51,"Diagnosis":"Flu","Gender":"Female","Risk_Score":51}
# {"Age":78,"Diagnosis":"Cold","Gender":"Male","Risk_Score":78}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":38,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":38}
# {"Age":34,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":34}
# {"Age":52,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":52}
# {"Age":47,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":47}
# {"Age":43,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":43}
# {"Age":49,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":49}
# {"Age":64,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":64}
# {"Age":63,"Diagnosis":"Flu","Gender":"Female","Risk_Score":63}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":25}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":57}
# {"Age":19,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":19}
# {"Age":53,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":53}
# {"Age":74,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":74}
# {"Age":37,"Diagnosis":"Pneumonia","Gender":"Male","Risk_Score":37}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":45}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":70}
# {"Age":58,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":58}
# {"Age":41,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":41}
# {"Age":42,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":42}
# {"Age":42,"Diagnosis":"Flu","Gender":"Male","Risk_Score":42}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":70}
# {"Age":51,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":51}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":45}
# {"Age":73,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":73}
# {"Age":52,"Diagnosis":"Flu","Gender":"Female","Risk_Score":52}
# {"Age":42,"Diagnosis":"Flu","Gender":"Male","Risk_Score":42}
# {"Age":22,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":22}
# {"Age":54,"Diagnosis":"Flu","Gender":"Female","Risk_Score":54}
# {"Age":75,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":75}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":18,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":18}
# {"Age":64,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":64}
# {"Age":49,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":49}
# {"Age":48,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":48}
# {"Age":76,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":76}
# {"Age":44,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":44}
# {"Age":42,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":42}
# {"Age":70,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":70}
# {"Age":71,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":71}
# {"Age":46,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":46}
# {"Age":75,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":75}
# {"Age":75,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":75}
# {"Age":63,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":63}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":36,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":36}
# {"Age":25,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":25}
# {"Age":52,"Diagnosis":"Cold","Gender":"Male","Risk_Score":52}
# {"Age":78,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":78}
# {"Age":62,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":62}
# {"Age":57,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":57}
# {"Age":28,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":28}
# {"Age":61,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":61}
# {"Age":25,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":25}
# {"Age":29,"Diagnosis":"Cold","Gender":"Female","Risk_Score":29}
# {"Age":60,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":60}
# {"Age":74,"Diagnosis":"Bronchitis","Gender":"Male","Risk_Score":74}
# {"Age":77,"Diagnosis":"Flu","Gender":"Female","Risk_Score":77}
# {"Age":22,"Diagnosis":"Flu","Gender":"Female","Risk_Score":22}
# {"Age":31,"Diagnosis":"Cold","Gender":"Female","Risk_Score":31}
# {"Age":23,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":23}
# {"Age":75,"Diagnosis":"Cold","Gender":"Male","Risk_Score":75}
# {"Age":79,"Diagnosis":"Healthy","Gender":"Male","Risk_Score":79}
# {"Age":56,"Diagnosis":"Bronchitis","Gender":"Female","Risk_Score":56}
# {"Age":45,"Diagnosis":"Healthy","Gender":"Female","Risk_Score":45}

# %%
#converted to JSON display only first rows since above file is huge^
transit_json = df.to_json(orient='records', indent=4)
transit_deserialized = json.loads(transit_json)
print(json.dumps(transit_deserialized[:5], indent=4))
# Out:
# [
#     {
#         "Patient_ID": 1,
#         "Age": 74,
#         "Gender": "Male",
#         "Symptom_1": "Fatigue",
#         "Symptom_2": "Sore throat",
#         "Symptom_3": "Fever",
#         "Heart_Rate_bpm": 69,
#         "Body_Temperature_C": 39.4,
#         "Blood_Pressure_mmHg": "132/91",
#         "Oxygen_Saturation_%": 94,
#         "Diagnosis": "Flu",
#         "Severity": "Moderate",
#         "Treatment_Plan": "Medication and rest"
#     },
#     {
#         "Patient_ID": 2,
#         "Age": 66,
#         "Gender": "Female",
#         "Symptom_1": "Sore throat",
#         "Symptom_2": "Fatigue",
#         "Symptom_3": "Cough",
#         "Heart_Rate_bpm": 95,
#         "Body_Temperature_C": 39.0,
#         "Blood_Pressure_mmHg": "174/98",
#         "Oxygen_Saturation_%": 98,
#         "Diagnosis": "Healthy",
#         "Severity": "Mild",
#         "Treatment_Plan": "Rest and fluids"
#     },
#     {
#         "Patient_ID": 3,
#         "Age": 32,
#         "Gender": "Male",
#         "Symptom_1": "Body ache",
#         "Symptom_2": "Sore throat",
#         "Symptom_3": "Fatigue",
#         "Heart_Rate_bpm": 77,
#         "Body_Temperature_C": 36.8,
#         "Blood_Pressure_mmHg": "136/60",
#         "Oxygen_Saturation_%": 96,
#         "Diagnosis": "Healthy",
#         "Severity": "Mild",
#         "Treatment_Plan": "Rest and fluids"
#     },
#     {
#         "Patient_ID": 4,
#         "Age": 21,
#         "Gender": "Female",
#         "Symptom_1": "Shortness of breath",
#         "Symptom_2": "Headache",
#         "Symptom_3": "Cough",
#         "Heart_Rate_bpm": 72,
#         "Body_Temperature_C": 38.9,
#         "Blood_Pressure_mmHg": "147/82",
#         "Oxygen_Saturation_%": 99,
#         "Diagnosis": "Healthy",
#         "Severity": "Mild",
#         "Treatment_Plan": "Rest and fluids"
#     },
#     {
#         "Patient_ID": 5,
#         "Age": 53,
#         "Gender": "Male",
#         "Symptom_1": "Runny nose",
#         "Symptom_2": "Sore throat",
#         "Symptom_3": "Fatigue",
#         "Heart_Rate_bpm": 100,
#         "Body_Temperature_C": 36.6,
#         "Blood_Pressure_mmHg": "109/106",
#         "Oxygen_Saturation_%": 92,
#         "Diagnosis": "Healthy",
#         "Severity": "Mild",
#         "Treatment_Plan": "Rest and fluids"
#     }
# ]

# %%
#convert CSV to SQL display:
process_data(csv_file, output_format_sql, db_name=db_name, table_name=table_name)
# Out:
# DataFrame saved to SQLite database disease_database.db, table: disease_table.
#
# Displaying the data from the SQL table:
#    Age Diagnosis  Gender  Risk_Score
# 0   74       Flu    Male          74
# 1   66   Healthy  Female          66
# 2   32   Healthy    Male          32
# 3   21   Healthy  Female          21
# 4   53   Healthy    Male          53

# %%
# JSON Dataset
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rmisra/news-category-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/rmisra/news-category-dataset/versions/3

# %%
#JSON to dataframe

json_data = os.path.join(path, "News_Category_Dataset_v3.json")
df_json = pd.read_json(json_data, lines=True)

print(df_json.head())
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22

# %%
# modifying JSON file (dropping and adding new column)
df_json.drop(columns=['link'], inplace=True)

print("Dropped column: 'link'")

# new column 'Source_Type'
df_json['Source_Type'] = 'News'

# modified DataFrame
print("Modified DataFrame:")
print(df_json.head())
# Out:
# Dropped column: 'link'
# Modified DataFrame:
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date Source_Type
# 0 2022-09-23        News
# 1 2022-09-23        News
# 2 2022-09-23        News
# 3 2022-09-23        News
# 4 2022-09-22        News

# %%
#JSON to CSV
csv_output_file = 'news_category.csv'
df_json.to_csv(csv_output_file, index=False)

print(f"JSON file converted to CSV and saved to {csv_output_file}.")
print(df_json.head())
# Out:
# JSON file converted to CSV and saved to news_category.csv.
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date Source_Type
# 0 2022-09-23        News
# 1 2022-09-23        News
# 2 2022-09-23        News
# 3 2022-09-23        News
# 4 2022-09-22        News

# %%
#into SQL database file
db_file = 'news_category.db'
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS news_category (
    category TEXT,
    headline TEXT,
    authors TEXT,
    source_type TEXT -- Adjust based on actual CSV columns
)
''')

#CSV data into the table
import csv

with open('news_category.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        cursor.execute('''
        INSERT INTO news_category (category, headline, authors, source_type)
        VALUES (?, ?, ?, ?)
        ''', (row['category'], row['headline'], row['authors'], row['Source_Type']))

rows = cursor.fetchall()

#commit and close connection
db_file = 'news_category.db'
conn = sqlite3.connect(db_file)
cursor = conn.cursor()
cursor.execute('SELECT * FROM news_category LIMIT 10')
rows = cursor.fetchall()

#display
print("Data from 'news_category' table:")
for row in rows:
    print(row)

#close the connection
conn.close()
# Out:
# Data from 'news_category' table:
# ('U.S. NEWS', 'Over 4 Million Americans Roll Up Sleeves For Omicron-Targeted COVID Boosters', 'Carla K. Johnson, AP', 'News')
# ('U.S. NEWS', 'American Airlines Flyer Charged, Banned For Life After Punching Flight Attendant On Video', 'Mary Papenfuss', 'News')
# ('COMEDY', '23 Of The Funniest Tweets About Cats And Dogs This Week (Sept. 17-23)', 'Elyse Wanshel', 'News')
# ('PARENTING', 'The Funniest Tweets From Parents This Week (Sept. 17-23)', 'Caroline Bologna', 'News')
# ('U.S. NEWS', 'Woman Who Called Cops On Black Bird-Watcher Loses Lawsuit Against Ex-Employer', 'Nina Golgowski', 'News')
# ('U.S. NEWS', 'Cleaner Was Dead In Belk Bathroom For 4 Days Before Body Found: Police', '', 'News')
# ('U.S. NEWS', 'Reporter Gets Adorable Surprise From Her Boyfriend While Live On TV', 'Elyse Wanshel', 'News')
# ('WORLD NEWS', 'Puerto Ricans Desperate For Water After Hurricane Fiona’s Rampage', 'DÁNICA COTO, AP', 'News')
# ('CULTURE & ARTS', 'How A New Documentary Captures The Complexity Of Being A Child Of Immigrants', 'Marina Fang', 'News')
# ('WORLD NEWS', "Biden At UN To Call Russian War An Affront To Body's Charter", 'Aamer Madhani, AP', 'News')

# %%
#data ingestion summary for SECOND dataset (JSON to CSV into SQL)
csv_output_file = 'news_category.csv'

df_json = pd.read_csv(csv_output_file)

#summary function
def generate_summary(df, stage):
    num_records = df.shape[0]
    num_columns = df.shape[1]
    print(f"{stage} Summary:")
    print(f"Number of records: {num_records}")
    print(f"Number of columns: {num_columns}")
    print("="*30)

#summary after ingestion
generate_summary(df_json, "Ingestion")

#summary after modification
generate_summary(df_json, "Post-Processing")

#modified DataFrame to SQL Database
db_file = 'news_category.db'
conn = sqlite3.connect(db_file)
df_json.to_sql('news_category', conn, if_exists='replace', index=False)

print(f"Data saved to SQL database at {db_file}.")
conn.close()
# Out:
# Ingestion Summary:
# Number of records: 209527
# Number of columns: 6
# ==============================
# Post-Processing Summary:
# Number of records: 209527
# Number of columns: 6
# ==============================
# Data saved to SQL database at news_category.db.

# %%
#data ingestion summary for FIRST dataset (CSV to JSON into SQL)
csv_file_path = os.path.join(path, 'disease_diagnosis.csv')
df_disease = pd.read_csv(csv_file_path)

def generate_summary(df, stage):
    num_records = df.shape[0]
    num_columns = df.shape[1]
    print(f"{stage} Summary:")
    print(f"Number of records: {num_records}")
    print(f"Number of columns: {num_columns}")
    print("=" * 30)

#summary after ingestion for the disease dataset
generate_summary(df_disease, "Ingestion")

three_selected_columns = ['Age', 'Diagnosis', 'Gender']
df_modified = mod_columns(df_disease, three_selected_columns)

#summary after modifications
generate_summary(df_modified, "Post-Processing")
# Out:
# Ingestion Summary:
# Number of records: 2000
# Number of columns: 13
# ==============================
# Post-Processing Summary:
# Number of records: 2000
# Number of columns: 4
# ==============================
