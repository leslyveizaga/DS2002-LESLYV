# %%
# !pip install --upgrade pymongo certifi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 17.7 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
import pprint

# %%
connection_string = "mongodb+srv://leslyveizaga1:password.@cluster0.d52zb.mongodb.net/test?retryWrites=true&w=majority"
client = MongoClient(connection_string)

# %%
db = client['sample_mflix']
collection = db['movies']

# %%
#1. Write a query to find the first movie that has the genre "Action".
action_movies= collection.find({"genres":"Action"}).limit(1)
# print("First movie genre Action", action_movies)
# pprint.pprint(action_movies)
for movie in action_movies:
  pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1391f29313caabcd8268'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Billie Dove', 'Tempe Pigott', 'Donald Crisp', 'Sam De Grasse'],
#  'countries': ['USA'],
#  'directors': ['Albert Parker'],
#  'fullplot': 'A nobleman vows to avenge the death of his father at the hands '
#              'of pirates. To this end he infiltrates the pirate band. Acting '
#              'in character he is instrumental in the capture of a ship, but '
#              'things are complicated when he finds that there is a young woman '
#              'on board whom he wishes to protect from the threat of rape.',
#  'genres': ['Adventure', 'Action'],
#  'imdb': {'id': 16654, 'rating': 7.2, 'votes': 1146},
#  'lastupdated': '2015-08-22 01:10:11.970000000',
#  'num_mflix_comments': 1,
#  'plot': 'Seeking revenge, an athletic young man joins the pirate band '
#          "responsible for his father's death.",
# ...

# %%
#2. Write a query to find all movies released after the year 2000 (Return the first 5 results).
movies_after_2000= collection.find({"year": {"$gt": 2000}}).limit(5)
for movie in movies_after_2000:
  pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1393f29313caabcdcb42'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
# ...

# %%
#4. Write a query to find all movies where the genre contains both "Action" and "Adventure".
movies_action_adventure= collection.find ({"$and": [{"genres": "Action"}, {"genres": "Adventure"}]})
for movie in movies_action_adventure:
  pprint.pprint(movie)
# Out:
# Streaming output truncated to the last 5000 lines.
#              'with a seemingly incomprehensible partner, Reid pursues the '
#              'criminal against all obstacles. However, John and Tonto learn '
#              'that Cavendish is only part of a far greater injustice and the '
#              'pair must fight it in an adventure that would make them a '
#              'legend.',
#  'genres': ['Action', 'Adventure', 'Western'],
#  'imdb': {'id': 1210819, 'rating': 6.5, 'votes': 166042},
#  'languages': ['English', 'North American Indian'],
#  'lastupdated': '2015-08-31 00:07:58.123000000',
#  'metacritic': 37,
#  'num_mflix_comments': 0,
#  'plot': 'Native American warrior Tonto recounts the untold tales that '
#          'transformed John Reid, a man of the law, into a legend of justice.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjFiMTc2MTAtZDA0My00OGRmLTk5M2ItNTlmYTUwZmU2YmRiXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
# ...

# %%
#2.1. Write a query to find all movies where the genre is "Comedy" and sort them by IMDb rating in descending order (Return the first 5 results).
movies_comedy= collection.find({"genres":"Comedy"}).sort("IMDb", -1).limit(5)
for movie in movies_comedy:
  pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1391f29313caabcd79e4'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Buster Keaton', 'Margaret Leahy', 'Wallace Beery', 'Joe Roberts'],
#  'countries': ['USA'],
#  'directors': ['Edward F. Cline', 'Buster Keaton'],
#  'fullplot': 'In his first independently produced feature film Buster tells of '
#              'love and romance through three historical ages: the Stone Age, '
#              'the Roman Age, and the Modern Age.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 14538, 'rating': 7.2, 'votes': 2628},
#  'lastupdated': '2015-08-05 01:02:46.273000000',
#  'num_mflix_comments': 0,
#  'plot': 'The misadventures of Buster in three separate historical periods.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI3OTEzODA4NF5BMl5BanBnXkFtZTgwODc0NDIwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1923, 9, 24, 0, 0),
#  'runtime': 63,
#  'title': 'Three Ages',
# ...

# %%
#2.2 Write a query to find all movies where the genre is "Drama" and sort them by release year in ascending order (Return the first 5 results).
sort_drama_movies = collection.find({"genres": "Drama"}, {"title": 1}).sort("year", 1).limit (5)
print("Drama movies")

for movie in sort_drama_movies:
  print(movie["title"])
# Out:
# Drama movies
# A Corner in Wheat
# Traffic in Souls
# In the Land of the Head Hunters
# Regeneration
# The Italian

# %%
#3.1. Write an aggregation pipeline that calculates the average IMDb rating for each genre (Return the top 5 genres).
avg_imdb_rating_genre = collection.aggregate([
    {"$unwind": "$genres"},
     {"$group": {"_id": "$genres", "avg_rating": {"$avg": "$imdb.rating"}}},
      {"$sort": {"avg_rating":-1}},
      {"$limit": 5}
])
print("T5 Genres by Average IMDb Rating:")
for genre in avg_imdb_rating_genre:
  print(f"{genre['_id']}: {genre['avg_rating']}")
# Out:
# T5 Genres by Average IMDb Rating:
# Film-Noir: 7.397402597402598
# Short: 7.377574370709382
# Documentary: 7.365679824561403
# News: 7.252272727272728
# History: 7.1696100917431185

# %%
#3.2. Write an aggregation pipeline to find the top 5 directors by the average IMDb rating of their movies.
t5_directors = collection.aggregate([
   {"$group": {"_id": "$directors", "avg_rating": {"$avg": "$imdb.rating"}}},
   {"$sort": {"avg_rating": -1}},
   {"$limit":5}
])
print("T5 Directors with Average IMDb Rating:")
for director in t5_directors:
  print (f"{director['_id']}:{director['avg_rating']}")
# Out:
# T5 Directors with Average IMDb Rating:
# ['Sara Hirsh Bordo']:9.4
# ['Kevin Derek']:9.3
# ['Michael Benson']:9.0
# ['Slobodan Sijan']:8.95
# ['Jeethu Joseph']:8.9

# %%
#3.3. Write an aggregation pipeline to calculate the total number of movies released in each year (Sort the results by the year).
movies_each_year = collection.aggregate([
    {"$group": {"_id": "$year", "total_movies": {"$sum": 1}}},
    {"$sort": {"_id": 1}}
])

print("Total Movies Released by Year:")
for year in movies_each_year:
  print(f"{year['_id']}: {year['total_movies']}")
# Out:
# Total Movies Released by Year:
# 1896: 2
# 1903: 1
# 1909: 1
# 1911: 2
# 1913: 1
# 1914: 3
# 1915: 2
# 1916: 2
# 1917: 2
# 1918: 1
# 1919: 1
# 1920: 4
# 1921: 5
# 1922: 3
# 1923: 2
# 1924: 6
# 1925: 3
# 1926: 6
# 1927: 4
# 1928: 8
# 1929: 7
# 1930: 10
# 1931: 20
# 1932: 18
# 1933: 20
# 1934: 23
# 1935: 31
# 1936: 30
# 1937: 31
# 1938: 38
# 1939: 20
# 1940: 24
# 1941: 24
# 1942: 30
# 1943: 32
# 1944: 23
# 1945: 29
# 1946: 34
# 1947: 29
# 1948: 56
# 1949: 52
# 1950: 55
# 1951: 54
# 1952: 45
# 1953: 65
# 1954: 47
# 1955: 67
# 1956: 67
# 1957: 71
# 1958: 75
# 1959: 71
# 1960: 73
# 1961: 68
# 1962: 70
# 1963: 69
# 1964: 86
# 1965: 77
# 1966: 87
# 1967: 81
# 1968: 89
# 1969: 107
# 1970: 120
# 1971: 106
# 1972: 121
# 1973: 112
# 1974: 103
# 1975: 107
# 1976: 116
# 1977: 123
# 1978: 128
# 1979: 131
# 1980: 167
# 1981: 168
# 1982: 177
# 1983: 161
# 1984: 199
# 1985: 189
# 1986: 190
# 1987: 222
# 1988: 251
# 1989: 232
# 1990: 225
# 1991: 238
# 1992: 270
# 1993: 274
# 1994: 305
# 1995: 372
# ...

# %%
#4.1. Write a query to update the IMDb rating of a movie with the title "The Godfather" to 9.5.
collection.update_one({"title": "The Godfather"}, {"$set": {"imdb.rating": 9.5}})
print("UTD imdb rating The Godfather 9.5")
# Out:
# UTD imdb rating The Godfather 9.5

# %%
#4.2. Write a query to update all movies where the genre is "Horror" and set their IMDb rating to 6.0 if it is currently null.
collection.update_many({"genres": "Horror", "imdb.rating": {"$exists": False}}, {"$set": {"imdb.rating": 6.0}})
print("UTD imdb rating horror movies to 6.0 null")
# Out:
# UTD imdb rating horror movies to 6.0 null

# %%
#4.3. Write a query to delete all movies that were released before the year 1950.
collection.delete_many({"year": {"$lt": 1950}})
print("deleted movies before 1950")
# Out:
# deleted movies before 1950

# %%
#5.1. Ensure the title field is indexed for text search in MongoDB and write a query to search for movies that contain the word "love" in their title.
love_movies_title= collection.find(
    {"$text":{"$search":"love"}},
     {"_id": 0, "title": 1, "year": 1, "imdb.rating": 1} )

for movie in love_movies_title:
  print(movie)
# Out:
# {'imdb': {'rating': 5.5}, 'year': 2003, 'title': "It's All About Love"}
# {'title': 'He Loves Me... He Loves Me Not', 'year': 2002, 'imdb': {'rating': 7.3}}
# {'title': 'The Loving Story', 'year': 2011, 'imdb': {'rating': 7.5}}
# {'title': 'Crazy Love', 'year': 1987, 'imdb': {'rating': 7.0}}
# {'title': 'Endless Love', 'year': 1981, 'imdb': {'rating': 4.7}}
# {'imdb': {'rating': 7.7}, 'year': 2003, 'title': 'Love Actually'}
# {'title': 'Love, Money, Love', 'year': 2000, 'imdb': {'rating': 4.0}}
# {'imdb': {'rating': 6.5}, 'year': 1999, 'title': 'For Love of the Game'}
# {'imdb': {'rating': 6.3}, 'year': 2008, 'title': 'The Edge of Love'}
# {'title': 'Love and Death', 'year': 1975, 'imdb': {'rating': 7.8}}
# {'title': 'The Dark Matter of Love', 'year': 2012, 'imdb': {'rating': 7.4}}
# {'imdb': {'rating': 6.4}, 'year': 2007, 'title': 'Love in the Time of Cholera'}
# {'title': 'Love Sick', 'year': 2006, 'imdb': {'rating': 7.0}}
# ...

# %%
#5.2 Write a text search query to find movies where the word "war" appears in the title or plot, sorted by IMDb rating (Return only the top 5 results).

war_movies = collection. find (
    {"$text": {"$search": "war"}},
    {"_id": 0, "title": 1}
). sort("imdb. rating", -1).limit (5)

for movie in war_movies:
  print(movie)
# Out:
# {'title': 'Of Men and War'}
# {'title': 'War Photographer'}
# {'title': 'The Civil War'}
# {'title': 'The Civil War'}
# {'title': 'Oh! What a Lovely War'}

# %%
#6.1. Write a query to find all movies where the genre is "Action" and the IMDb rating is greater than 8 (Sort the results by release year in descending order).
#"year": {"$gt": 2000}}).limit(5)
#({"$and": [{"genres": "Action"}, {"genres": "Adventure"}]})
action_imdb_8= collection.find({"$and": [{"genres": "Action"}, {"imdb.rating": {"$gt": 8}}]}).sort("year", -1).limit(5)
for movie in action_imdb_8:
  pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13bef29313caabd5b166'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Vladimir Mashkov',
#           'Mikhail Porechenkov',
#           'Vladimir Menshov',
#           'Sergey Makovetskiy'],
#  'countries': ['Russia'],
#  'genres': ['Action', 'Thriller'],
#  'imdb': {'id': 1048097, 'rating': 8.6, 'votes': 929},
#  'languages': ['Russian', 'Ukrainian'],
#  'lastupdated': '2015-04-08 00:08:01.207000000',
#  'num_mflix_comments': 1,
#  'released': datetime.datetime(2007, 12, 2, 0, 0),
#  'runtime': 45,
#  'title': 'Liquidation',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 17, 10, 27),
#               'viewer': {'meter': 23, 'numReviews': 83, 'rating': 1.9}},
#  'type': 'series',
#  'year': '2007è'}
# {'_id': ObjectId('573a13b6f29313caabd48af3'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
# ...

# %%
#6.2. Write a query to find all movies where the directors contain "Christopher Nolan" and the IMDb rating is greater than 8 (Return only the top 3 movies sorted by rating).
Christopher_nolan_imdb_8= collection.find({"$and": [{"director": "Christopher Nolan"}, {"imdb.rating": {"$gt": 8}}]}).sort("imdb.rating", -1).limit(3)
for movie in Christopher_nolan_imdb_8:
  print (movie)
